# %% [markdown]
# <h1 style="color:blue"><center>TP2 Interpolation Numérique</center></h1>

# %% [markdown]
# <h2>Objectifs:</h2>
# <p> Dans ce TP nous avons étudié les deux méthodes de l'intérpolation polynomiale qui sont :</p>
# <p>- Méthode de Lagrange </p>
# <p>- Méthode de Newton</p>

# %% [markdown]
# <h2>Définitions</h2>
# <p><b>Méthode de Lagrange : </b> </p>
# <p>permet de trouver les points stationnaires (maximum, minimum…) d'une fonction dérivable d'une ou plusieurs variables, sous contraintes.</p>
# <p><b>Méthode de Newton </b></p>
# <p>ne méthode d'interpolation polynomiale permettant d'obtenir le polynôme de Lagrange comme combinaison linéaire de polynômes de la « base newtonienne ».</p>

# %% [markdown]
# ## Exercice 1

# %%
from numpy import prod
def prog(x,y,c):
    S = [] 
    n = len(x)
    
    for j in range(n):
        L =[c-xx for xx in x]
        for k in range(n):
            if (k == j):                
                L[k] = 1
            else:
                L[k] = L[k]/(x[j] - x[k])   
        S.append(y[j]*prod(L))
        
    return  sum(S)

# %%
X=[1 ,2 ,3 ,4,-2];
Y=[-1, 0, 2 ,1,3];
for i in X:
    print(prog(X,Y,i))
sum(X)
# Out:
# -1.0
# 0.0
# 2.0
# 1.0
# 3.0
# 8

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# la courbe du polynome de Lagrange qui passe par les points suports suivant
#(1,-1),(2,3)(3,2),(4,1)
X=[1,2,3,4]
Y=[-1,3,2,1]
t=np.linspace(-1,5,201)
len(t)
imaget=[prog(X,Y,i) for i in t]
plt.plot(t,imaget,'r')
plt.plot(X,Y,'ob')
plt.grid(True)
plt.show()

# %% [markdown]
# **Polynome d'interpolation de Lagrange**
# > Soient $(x_0,y_0), \ldots,(x_k,y_k),\ldots ,(x_n,k_n)$ $n+1$ points deux à deux distincts, le polynôme d'interpolation de Lagrange associés à ces points supports est défini par :
# > $$P_n(x)=\sum_{k=0}^{n-1} y_kL_k(x)$$
#
# avec $L_{0}(x)=\displaystyle\frac{(x-x_1)(x-x_2)\ldots(x-x_{n})}{(x_0-x_1)(x_0-x_2)\ldots(x_0-x_{n})}$ et $L_{k}(x)=\displaystyle\frac{(x-x_1)(x-x_2)\ldots(x-x_{k-1})(x-x_{k+1})\ldots(x_0-x_{n})}{(x_k-x_0)(x_k-x_1)\ldots(x_k-x_{k-1})(x_k-x_{k+1})\ldots(x_k-x_{n})}$ pour $k\in \{1,\ldots,n\}$

# %% [markdown]
# 1) Que renvoie la fonction PR lorsqu'on lui déclare  **x=(x(1),x(2),...,x(n))x=(x(1),x(2),...,x(n))**  et  **y=(y(1),y(2),...,y(n))y=(y(1),y(2),...,y(n))**  deux vecteurs de même longueur  `n` et `c`  un nombre réel donné.

# %% [markdown]
# ## Code Python

# %%
from numpy import prod  
def PR(x,y,c):
    S=[]
    n = len(x)
    for j in range(n):
        L = [c-u for u in x]
        for k in range (n):
            if k ==j :
                L[k]=1
            else:
                L[k]= L[k]/(x[j]-x[k])
        S.append(y[j] * prod(L))
    return sum(S)

# %%
X=[1,2,3,4];
Y=[-1,0,2,1];
for k in X: 
    print(PR(X,Y,k))
# Out:
# -1.0
# 0.0
# 2.0
# 1.0

# %% [markdown]
# 2) Que contient le vecteur  LL  après la fin de la boucle  kk .

# %%
x=[1,2,3,4];
y=[-1,0,2,1];

# %%
S = y 
n = len(x)
for c in X:
    for j in range(n):
        L = [c-u for u in x]
        for k in  range(n):
            if (k == j):
                L[k] = 1
            else:
                L[k] = L[k]/(x[j] - x[k])
            S.append(y[j]*prod(L))
        
    u=sum(S)

# %%
print(L)
# Out:
# [1.0, 1.0, 1.0, 1]

# %% [markdown]
# 3) Utiliser cette fonction pour dessiner le graph du polynôme de Lagrange  de la fonction $f(x) = \dfrac{1}{1 + x^2}$ aux points $x=[-1:0.1:1]$.

# %%
x=np.arange(-1,1,0.5);
f=lambda x: 1/(1+x**2)
y=f(x)
t=np.linspace(-1,1,100)
imaget=[f(x)for i in t]
imaget=[prog(x,y,i)for i in t]
plt.plot(t,imaget,'r',x,y,'bo',t,imaget,'g')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
from numpy import linspace
import numpy as np
x=np.arange(-1,1,0.1)
pt=[]
f=lambda x: 1/(1+x**2)
y=f(x)
t=np.linspace(-1,1,100)
for u in range(len(t)):
    pt.append(PR(x,y,t[u]))
plt.plot(t,pt,x,y,'bo',t,f(t),'g')
# Out:
# [<matplotlib.lines.Line2D at 0x187326dadf0>,
#  <matplotlib.lines.Line2D at 0x187326daeb0>,
#  <matplotlib.lines.Line2D at 0x187326daee0>]

# %%
from scipy.interpolate import lagrange
import numpy as np 
x = np.array([-1, 0.1, 1])
y = 1/(1+x**2)
poly = lagrange(x,y)
print("la polynome de Lagrange de la fonction f(x) est :")
print(poly)
# Out:
# la polynome de Lagrange de la fonction f(x) est :
#         2
# -0.495 x + 0.995

# %%
import matplotlib.pyplot as plt
from numpy import linspace
f=poly
T=linspace(-1,1,100)
plt.title('le polynome de Lagrange de f(x)')
plt.plot(T,f(T),'pink')    
plt.show()

# %% [markdown]
# 4) On considère la fonction $F$ suivante :
# $$
# F(h) = \pi -\cos \left(\frac{h}{2}\right) + h \sqrt{1-\left(\frac{h}{2}\right)^2}, \qquad
# h\in [0,2],
# $$
# et les points d'interpolation $x_i = ih$, $0\leq i\leq n$, avec $ n=20$ et $h=0.1$.

# %% [markdown]
# 4.1) Représenter sur un même graphe la fonction $F$ et $p_n$, où
#  $p_n$ est le polynôme d'interpolation de Lagrange de $F$ aux
#  points $x_0,\,\ldots,\,x_n$.

# %%
import matplotlib.pyplot as plt
import math
from numpy import linspace

f=lambda x:np.pi-np.cos(x/2)+x*np.sqrt((1-(x/2)**2))
t=linspace(-1,1,100)
plt.plot (t,f(t),'g',label="F(X)")
plt.legend()
plt.show()


from scipy.interpolate import lagrange
x=np.array([0,1,2])
y= np.pi-np.cos(x/2)+x*np.sqrt((1-(x/2)**2))
poly=lagrange(x,y)
print(poly)



import matplotlib.pyplot as plt
f=poly
t=linspace(-1,2,100)
plt.title("Polynome de Lagrange de f(x)")
plt.plot(t,f(t),'g')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
#          2
# -0.7586 x + 1.747 x + 2.142

# %%
import matplotlib.pyplot as plt 
from numpy import linspace
import numpy as np
f=lambda x: np.pi-np.cos(x/2)+ x*np.sqrt((1-(x/2)**2))
t=linspace(-1,2,100)
plt.plot(t,f(t),'b',label="F(x)")
g=poly
plt.plot(t,g(t),'g',label="Polynome de Lagrange")
plt.legend()
plt.show()

# %% [markdown]
# 2)Tracer la courbe d'erreur  (la
#  fonction $F-p_n$). Qu'observer vous.

# %%
x=np.arange(0,2)
f= lambda x: np.pi-np.cos(x/2)+x*np.sqrt(1-(x/2)**2)
y=f(x)

for u in np.arange (len(t)):
    pn=PR(x,y,t[u])
plt.plot(t,f(t)-pn,'r')

# %% [markdown]
# ## Exercice 2  ( Phenomène de Runge )

# %% [markdown]
# 1) Vérifier que sur $[-5,5]$ le polynôme d'interpolation de Lagrange
#   de la fonction $f$ définie par $f(x)=\displaystyle{\frac{1}{1+x^2}}$,
# en $N$ points uniformément espacés ne convergent pas correctement aux voisinages de $-1$ et $1$, pour $N=7,8,9,10 ...$

# %%
import numpy as np
from numpy import linspace
import matplotlib.pyplot as plt 

N=7
X=np.linspace(-5,5,N)
f=lambda x: 1/(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r',X,Y,'ob', t,np.polyval(p,t),'g')
plt.title("Interpolation Equidistante avec N=7")
##############################
N=8
X=np.linspace(-5,5,N)
f=lambda x: 1/(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("Interpolation Equidistante avec N=8")
##############################
N=9
X=np.linspace(-5,5,N)
f=lambda x:1/(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("Interpolation Equidistante avec N=9")
##############################
N=10
X=np.linspace(-5,5,N)
f=lambda x: 1/(1+x**2);
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("Interpolation Equidistante avec N=10")
plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=1.5, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.5)

# %% [markdown]
# 2) Les points de Tchebycheff sur un intervalle $[a;b]$ sont définie par :
#   $$x_k=\dfrac{a+b}{2}+\dfrac{a-b}{2}\cos\left(\frac{k-1}{n-1}\pi\right)\hspace{0.5cm} (k=1,..,n: x_1=a:x_n=b)$$
#
#   Vérifier que sur $[-5; 5]$ ; l'interpolation polynômiale de $f(x) = \dfrac{1}{1 + x^2}$ ; en $N$ points de Tchebychev
# est meilleure qu'une  interpolation utilisant $N$ points uniforment espacés (on prendra $N=10, 11, 16, 17$).

# %%
import numpy as np
from math import *
def tcheb(a,b,n):
    V=[]
    for k in range(n):
        V.append((a+b)/2+(a-b)/2*np.cos((k-1)/(n-1)*pi))
        return V
        
print(tcheb(-5,5,10))    
print(tcheb(-5,5,11))
print(tcheb(-5,5,16))
print(tcheb(-5,5,17))
# Out:
# [-4.698463103929543]
# [-4.755282581475767]
# [-4.8907380036690284]
# [-4.903926402016152]

# %%
N=10
X=np.linspace(-5,5,N)
f=lambda x: 1/(1+x**2)
Xt=tcheb(-5,5,N)
Yt=[f(i) for i in Xt]
pt=np.polyfit(Xt,Yt,N-1)
fig=plt.figure(1,figsize=(8,6))
plt.subplot(2,2,1)
k=np.polyval(pt,t)
plt.plot(t,f(t),'r',Xt,Yt,'ob', t, k,'g')
plt.title("Interpolation Tchebycheff avec N=10")
###################################################
N=11
X=np.linspace(-5,5,N)
f=lambda x: 1/(1+x**2)
Xt=tcheb(-5,5,N);
Yt=[f(i) for i in Xt]
pt=np.polyfit(Xt,Yt,N-1)
plt.subplot(2,2,2)
k=np.polyval(pt,t)
plt.plot(t,f(t),'r',Xt,Yt,'ob', t, k,'g')
plt.title("Interpolation Tchebycheff avec N=11")
##########################################################
N=16
X=np.linspace(-5,5,N)
f=lambda x: 1/(1+x**2)
Xt=tcheb(-5,5,N);
Yt=[f(i) for i in Xt]
pt=np.polyfit(Xt,Yt,N-1)
plt.subplot(2,2,3)
k=np.polyval(pt,t)
plt.plot(t,f(t),'r',Xt,Yt,'ob', t, k,'g')
plt.title("Interpolation Tchebycheff avec N=16")
##########################################################
N=17
X=np.linspace(-5,5,N)
f=lambda x: 1/(1+x**2)
Xt=tcheb(-5,5,N);
Yt=[f(i) for i in Xt]
pt=np.polyfit(Xt,Yt,N-1)
plt.subplot(2,2,4)
k=np.polyval(pt,t)
plt.plot(t,f(t),'r',Xt,Yt,'ob', t, k,'g')
plt.title("Interpolation Tchebycheff avec N=17")
# Out:
# C:\Users\Client\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\Client\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\Client\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\Client\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 1.0, 'Interpolation Tchebycheff avec N=17')

# %% [markdown]
# ## Exercice 3

# %% [markdown]
# 1) Déterminer en utilisant les deux codes puis par un calcul à la main le polynôme de Newton pour les données suivantes :
#
#
# <center>
# <table>
#       $\begin{array}{|c|c|c|}
#    \hline
#    i & x_i  & y_i \\
#    \hline
#    0 &   -1  &   6 \\
#    1 &   0 &  1 \\
#    2 &  2  &  3 \\
#    3 &  5  &  66 \\
#    \hline
# \end{array}$
# </table>
# </center>

# %%
def intN(x,f):
    m=len(x)
    y=np.zeros(m)
    for k in range (1,m):
        y[k:m+1]=np.array(np.array(f[k:m+1])-np.array(f[k-1:m-1]))/(np.array(x[k:m+1])-np.array(x[0:m-k]))
    return y

# %%
x=[-1,0,2,5]
y=[6,1,3,66]
intN(x,y)
# Out:
# array([ 0.        , -5.        ,  0.66666667, 10.5       ])

# %%
def intNval(x,c,t):
    m=len(x)
    p=c[m-1]*np.ones(len(t))
    for k in range (m-2,-1,-1):
        p=p*np.array((np.array(t)-x[k]))+c[k]
    return p

# %%
x=[-1,0,2,5]
y=[6,1,3,66]
t=[0,1,2,3]
intNval(x,y,t)
# Out:
# array([   7., -118.,   27.,  838.])

# %% [markdown]
# 2) Donner le Graph du polynôme trouvé en 1) dans l'intervalle $[-1;5]$.

# %%
x=[-1,0,2,5]
y=[6,1,3,66]
f=intN(x,y);
plt.plot(x,f,'r',x,y,'ob')
# Out:
# [<matplotlib.lines.Line2D at 0x18732e40d30>,
#  <matplotlib.lines.Line2D at 0x18732e40ee0>]

# %% [markdown]
# 3) Calculer $P(1)$ en utilisant le polynôme trouvé en 1).

# %%
x=[-1,0,2,5]
y=[6,1,3,66]
t=[0,1,2,3]
p=intNval(x,y,t)
p[0]
# Out:
# 7.0

# %% [markdown]
# <h2>Conclusion</h2>

# %% [markdown]
# <p> La méthode de Newton est plus pratique puisque en ajoutant un nouveau point on ne doit pas refaire tout le calcul, nous conservons ce qu'on a obtenu et on termine notre travail. </p>
